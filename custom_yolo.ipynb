# %%
from ultralytics import YOLO
from PIL import Image

# %%
model1 = YOLO('/content/yolov8n_100e.pt')

test_image_path = '/content/1.png'
results = model1(test_image_path)

for r in results:
    im_array = r.plot()
    im = Image.fromarray(im_array[..., ::-1])
    display(im)
# Out:
# image 1/1 /content/1.png: 384x640 7 Faces, 173.7ms
# Speed: 9.7ms preprocess, 173.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=500x282>
